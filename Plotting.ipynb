# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("gradedata.csv")
df.plot()
plt.show()

# %%
df.plot(kind = "scatter", x = "exercise", y = "hours" )
plt.show()

# %%
df["exercise"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>
